# %%
import pandas as pd
import numpy as np

# loading dataset into the program
dataset1 = pd.read_csv('C:\ML\London 2000-01-01 to 2024-01-31.csv', index_col="datetime")
dataset2 = pd.read_csv(r'C:\ML\tfl-daily-cycle-hires.csv', index_col="Day", parse_dates=["Day"])

# filter dataset1 from 2010.07.30 to 2024.01.31 ?????
start_date = pd.to_datetime('2000-01-01')
end_date = pd.to_datetime('2010-07-29')

dataset1.index = pd.to_datetime(dataset1.index)
dataset1_filtered = dataset1[(dataset1.index < start_date) | (dataset1.index > end_date)]

# combining the two datasets
merged_data = pd.merge(dataset1_filtered, dataset2, left_index=True, right_index=True, how='outer')

# changing index data type into datetime
merged_data.index = pd.to_datetime(merged_data.index)
print(merged_data.index)

# Print with the merged data
pd.set_option('display.max_rows', None)  # display all rows
pd.set_option('display.max_columns', None)  # display all columns
pd.set_option('display.width', None)  # no limitation with width
print(merged_data.head())
print(merged_data.tail())
#print(merged_data)
print(merged_data.columns)

# Checking number of missing data in every column
print(merged_data.isnull().sum())

# checking percentage of missing data in a column
perc_missing_values = merged_data.isnull().sum()/merged_data.shape[0]
print(perc_missing_values)

# Filling in the missing data in columns by the previous day values
merged_data=merged_data.ffill()

# Checking again the number of missing data in every column after filling in the missing values
print(merged_data.isnull().sum())

# Checking datatypes of each column to ensure are of correct types for ML processing
print(merged_data.dtypes)

# Checking how many entries for each year to identify if there is any day weather record is missing
print(merged_data.index.year.value_counts().sort_index())

# print final dataset
final_dataset = merged_data.copy()
print(final_dataset.head())
print(final_dataset.tail())
print(final_dataset.shape)
# Out:
# DatetimeIndex(['2010-07-30', '2010-07-31', '2010-08-01', '2010-08-02',
#                '2010-08-03', '2010-08-04', '2010-08-05', '2010-08-06',
#                '2010-08-07', '2010-08-08',
#                ...
#                '2024-01-22', '2024-01-23', '2024-01-24', '2024-01-25',
#                '2024-01-26', '2024-01-27', '2024-01-28', '2024-01-29',
#                '2024-01-30', '2024-01-31'],
#               dtype='datetime64[ns]', name='datetime', length=4934, freq=None)
#               name  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# datetime
# 2010-07-30  london     22.3     14.0  17.9          22.3          14.0
# 2010-07-31  london     23.5     17.6  20.1          23.5          17.6
# 2010-08-01  london     22.8     15.3  18.8          22.8          15.3
# 2010-08-02  london     22.1     16.3  18.9          22.1          16.3
# 2010-08-03  london     21.8     13.0  18.0          21.8          13.0
#
#             feelslike   dew  humidity  precip  precipprob  precipcover  \
# datetime
# 2010-07-30       17.9  10.5      63.0   0.000           0         0.00
# 2010-07-31       20.1  14.3      71.3   1.995         100         8.33
# 2010-08-01       18.8  11.7      64.8   0.000           0         0.00
# 2010-08-02       18.9  11.1      60.9   0.299         100         4.17
# 2010-08-03       18.0  11.6      67.3   0.000           0         0.00
#
#            preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2010-07-30        NaN   0.0        0.0       NaN       21.3    250.6
# 2010-07-31       rain   0.0        0.0       NaN       22.7    242.6
# 2010-08-01        NaN   0.0        0.0       NaN       14.6    261.1
# 2010-08-02       rain   0.0        0.0       NaN       15.1    344.5
# 2010-08-03        NaN   0.0        0.0       NaN       20.0    247.9
#
#             sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2010-07-30            1014.8        60.3        32.9           266.8
# 2010-07-31            1011.6        64.1        31.1           250.6
# 2010-08-01            1013.2        62.3        38.7           243.3
# 2010-08-02            1016.6        63.3        36.6           273.9
# 2010-08-03            1016.0        54.3        30.7           273.1
#
#             solarenergy  uvindex  severerisk              sunrise  \
# datetime
# 2010-07-30         23.1      8.0         NaN  2010-07-30T05:20:54
# 2010-07-31         21.7      7.0         NaN  2010-07-31T05:22:23
# 2010-08-01         21.1      7.0         NaN  2010-08-01T05:23:52
# 2010-08-02         23.6      8.0         NaN  2010-08-02T05:25:22
# 2010-08-03         23.4      8.0         NaN  2010-08-03T05:26:53
#
#                          sunset  moonphase              conditions  \
# datetime
# 2010-07-30  2010-07-30T20:52:00       0.65        Partially cloudy
# 2010-07-31  2010-07-31T20:50:25       0.68  Rain, Partially cloudy
# 2010-08-01  2010-08-01T20:48:48       0.71        Partially cloudy
# 2010-08-02  2010-08-02T20:47:09       0.75  Rain, Partially cloudy
# 2010-08-03  2010-08-03T20:45:28       0.75        Partially cloudy
#
#                                                   description  \
# datetime
# 2010-07-30                  Partly cloudy throughout the day.
# 2010-07-31  Partly cloudy throughout the day with rain in ...
# 2010-08-01                  Partly cloudy throughout the day.
# 2010-08-02  Partly cloudy throughout the day with morning ...
# 2010-08-03                  Partly cloudy throughout the day.
#
#                          icon  \
# datetime
# 2010-07-30  partly-cloudy-day
# 2010-07-31               rain
# 2010-08-01  partly-cloudy-day
# 2010-08-02               rain
# 2010-08-03  partly-cloudy-day
#
#                                                      stations  \
# datetime
# 2010-07-30  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-07-31  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-08-01  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-08-02  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-08-03  376,909,999,903,672,000,000,000,000,000,000,00...
#
#            Number of Bicycle Hires
# datetime
# 2010-07-30                   6,897
# 2010-07-31                   5,564
# 2010-08-01                   4,303
# 2010-08-02                   6,642
# 2010-08-03                   7,966
#               name  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# datetime
# 2024-01-27  London      8.6      1.1   5.0           6.6          -0.6
# 2024-01-28  London     11.5      3.1   7.0          11.5           0.5
# 2024-01-29  London     12.1      8.6  10.8          12.1           7.2
# 2024-01-30  London     12.5      7.6   9.1          12.5           4.9
# 2024-01-31  London     12.1      6.8   8.8          12.1           4.3
#
#             feelslike  dew  humidity  precip  precipprob  precipcover  \
# datetime
# 2024-01-27        3.3  2.0      81.8   0.000           0         0.00
# 2024-01-28        5.4  4.1      82.4   0.000           0         0.00
# 2024-01-29       10.5  8.8      87.3   0.000           0         0.00
# 2024-01-30        7.5  5.3      77.5   0.000           0         0.00
# 2024-01-31        7.5  4.1      72.5   0.199         100         4.17
#
#            preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2024-01-27        NaN   0.0        0.0      29.8       18.1    180.3
# 2024-01-28        NaN   0.0        0.0      25.9       13.8    169.7
# 2024-01-29        NaN   0.0        0.0      33.9       20.8    182.3
# 2024-01-30       rain   0.0        0.0      60.8       29.0    257.7
# 2024-01-31       rain   0.0        0.0      40.7       25.7    231.3
#
#             sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2024-01-27            1032.7        33.1        15.9            46.0
# 2024-01-28            1022.7        33.5        15.2            51.8
# 2024-01-29            1022.0        95.9         8.4            35.6
# 2024-01-30            1027.4        96.1        24.9            15.6
# 2024-01-31            1029.7        98.2        21.9            26.4
#
#             solarenergy  uvindex  severerisk              sunrise  \
# datetime
# 2024-01-27          4.0      3.0        10.0  2024-01-27T07:46:54
# 2024-01-28          4.6      3.0        10.0  2024-01-28T07:45:32
# 2024-01-29          3.1      2.0        10.0  2024-01-29T07:44:08
# 2024-01-30          1.4      1.0        10.0  2024-01-30T07:42:42
# 2024-01-31          2.3      1.0        10.0  2024-01-31T07:41:14
#
#                          sunset  moonphase        conditions  \
# datetime
# 2024-01-27  2024-01-27T16:40:05       0.56  Partially cloudy
# 2024-01-28  2024-01-28T16:41:51       0.59  Partially cloudy
# 2024-01-29  2024-01-29T16:43:39       0.62          Overcast
# 2024-01-30  2024-01-30T16:45:26       0.66          Overcast
# 2024-01-31  2024-01-31T16:47:14       0.69    Rain, Overcast
#
#                                                   description  \
# datetime
# 2024-01-27                  Partly cloudy throughout the day.
# 2024-01-28                  Partly cloudy throughout the day.
# 2024-01-29                   Cloudy skies throughout the day.
# 2024-01-30                   Cloudy skies throughout the day.
# 2024-01-31  Cloudy skies throughout the day with morning r...
#
#                          icon  \
# datetime
# 2024-01-27  partly-cloudy-day
# 2024-01-28  partly-cloudy-day
# 2024-01-29             cloudy
# 2024-01-30             cloudy
# 2024-01-31               rain
#
#                                                      stations  \
# datetime
# 2024-01-27  03769099999,03680099999,F6665,03781099999,0367...
# 2024-01-28  03769099999,03680099999,D4121,03781099999,0367...
# 2024-01-29  03769099999,03680099999,D4121,03781099999,0367...
# 2024-01-30  03769099999,03680099999,D4121,03781099999,0367...
# 2024-01-31  03769099999,03680099999,D4121,03781099999,0367...
#
#            Number of Bicycle Hires
# datetime
# 2024-01-27                  16,959
# 2024-01-28                  15,540
# 2024-01-29                  22,839
# 2024-01-30                  22,303
# 2024-01-31                  24,505
# Index(['name', 'tempmax', 'tempmin', 'temp', 'feelslikemax', 'feelslikemin',
#        'feelslike', 'dew', 'humidity', 'precip', 'precipprob', 'precipcover',
#        'preciptype', 'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir',
#        'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation',
#        'solarenergy', 'uvindex', 'severerisk', 'sunrise', 'sunset',
#        'moonphase', 'conditions', 'description', 'icon', 'stations',
#        'Number of Bicycle Hires'],
#       dtype='object')
# name                          0
# tempmax                       0
# tempmin                       0
# temp                          0
# feelslikemax                  0
# feelslikemin                  0
# feelslike                     0
# dew                           0
# humidity                      0
# precip                        0
# precipprob                    0
# precipcover                   0
# preciptype                 1847
# snow                          0
# snowdepth                     0
# windgust                   2432
# windspeed                     0
# winddir                       0
# sealevelpressure              1
# cloudcover                    0
# visibility                    0
# solarradiation                0
# solarenergy                   0
# uvindex                       0
# severerisk                 4182
# sunrise                       0
# sunset                        0
# moonphase                     0
# conditions                    0
# description                   0
# icon                          0
# stations                      0
# Number of Bicycle Hires       0
# dtype: int64
# name                       0.000000
# tempmax                    0.000000
# tempmin                    0.000000
# temp                       0.000000
# feelslikemax               0.000000
# feelslikemin               0.000000
# feelslike                  0.000000
# dew                        0.000000
# humidity                   0.000000
# precip                     0.000000
# precipprob                 0.000000
# precipcover                0.000000
# preciptype                 0.374341
# snow                       0.000000
# snowdepth                  0.000000
# windgust                   0.492906
# windspeed                  0.000000
# winddir                    0.000000
# sealevelpressure           0.000203
# cloudcover                 0.000000
# visibility                 0.000000
# solarradiation             0.000000
# solarenergy                0.000000
# uvindex                    0.000000
# severerisk                 0.847588
# sunrise                    0.000000
# sunset                     0.000000
# moonphase                  0.000000
# conditions                 0.000000
# description                0.000000
# icon                       0.000000
# stations                   0.000000
# Number of Bicycle Hires    0.000000
# dtype: float64
# name                          0
# tempmax                       0
# tempmin                       0
# temp                          0
# feelslikemax                  0
# feelslikemin                  0
# feelslike                     0
# dew                           0
# humidity                      0
# precip                        0
# precipprob                    0
# precipcover                   0
# preciptype                    1
# snow                          0
# snowdepth                     0
# windgust                     22
# windspeed                     0
# winddir                       0
# sealevelpressure              0
# cloudcover                    0
# visibility                    0
# solarradiation                0
# solarenergy                   0
# uvindex                       0
# severerisk                 4182
# sunrise                       0
# sunset                        0
# moonphase                     0
# conditions                    0
# description                   0
# icon                          0
# stations                      0
# Number of Bicycle Hires       0
# dtype: int64
# name                        object
# tempmax                    float64
# tempmin                    float64
# temp                       float64
# feelslikemax               float64
# feelslikemin               float64
# feelslike                  float64
# dew                        float64
# humidity                   float64
# precip                     float64
# precipprob                   int64
# precipcover                float64
# preciptype                  object
# snow                       float64
# snowdepth                  float64
# windgust                   float64
# windspeed                  float64
# winddir                    float64
# sealevelpressure           float64
# cloudcover                 float64
# visibility                 float64
# solarradiation             float64
# solarenergy                float64
# uvindex                    float64
# severerisk                 float64
# sunrise                     object
# sunset                      object
# moonphase                  float64
# conditions                  object
# description                 object
# icon                        object
# stations                    object
# Number of Bicycle Hires     object
# dtype: object
# 2010    155
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024     31
# Name: datetime, dtype: int64
#               name  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# datetime
# 2010-07-30  london     22.3     14.0  17.9          22.3          14.0
# 2010-07-31  london     23.5     17.6  20.1          23.5          17.6
# 2010-08-01  london     22.8     15.3  18.8          22.8          15.3
# 2010-08-02  london     22.1     16.3  18.9          22.1          16.3
# 2010-08-03  london     21.8     13.0  18.0          21.8          13.0
#
#             feelslike   dew  humidity  precip  precipprob  precipcover  \
# datetime
# 2010-07-30       17.9  10.5      63.0   0.000           0         0.00
# 2010-07-31       20.1  14.3      71.3   1.995         100         8.33
# 2010-08-01       18.8  11.7      64.8   0.000           0         0.00
# 2010-08-02       18.9  11.1      60.9   0.299         100         4.17
# 2010-08-03       18.0  11.6      67.3   0.000           0         0.00
#
#            preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2010-07-30        NaN   0.0        0.0       NaN       21.3    250.6
# 2010-07-31       rain   0.0        0.0       NaN       22.7    242.6
# 2010-08-01       rain   0.0        0.0       NaN       14.6    261.1
# 2010-08-02       rain   0.0        0.0       NaN       15.1    344.5
# 2010-08-03       rain   0.0        0.0       NaN       20.0    247.9
#
#             sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2010-07-30            1014.8        60.3        32.9           266.8
# 2010-07-31            1011.6        64.1        31.1           250.6
# 2010-08-01            1013.2        62.3        38.7           243.3
# 2010-08-02            1016.6        63.3        36.6           273.9
# 2010-08-03            1016.0        54.3        30.7           273.1
#
#             solarenergy  uvindex  severerisk              sunrise  \
# datetime
# 2010-07-30         23.1      8.0         NaN  2010-07-30T05:20:54
# 2010-07-31         21.7      7.0         NaN  2010-07-31T05:22:23
# 2010-08-01         21.1      7.0         NaN  2010-08-01T05:23:52
# 2010-08-02         23.6      8.0         NaN  2010-08-02T05:25:22
# 2010-08-03         23.4      8.0         NaN  2010-08-03T05:26:53
#
#                          sunset  moonphase              conditions  \
# datetime
# 2010-07-30  2010-07-30T20:52:00       0.65        Partially cloudy
# 2010-07-31  2010-07-31T20:50:25       0.68  Rain, Partially cloudy
# 2010-08-01  2010-08-01T20:48:48       0.71        Partially cloudy
# 2010-08-02  2010-08-02T20:47:09       0.75  Rain, Partially cloudy
# 2010-08-03  2010-08-03T20:45:28       0.75        Partially cloudy
#
#                                                   description  \
# datetime
# 2010-07-30                  Partly cloudy throughout the day.
# 2010-07-31  Partly cloudy throughout the day with rain in ...
# 2010-08-01                  Partly cloudy throughout the day.
# 2010-08-02  Partly cloudy throughout the day with morning ...
# 2010-08-03                  Partly cloudy throughout the day.
#
#                          icon  \
# datetime
# 2010-07-30  partly-cloudy-day
# 2010-07-31               rain
# 2010-08-01  partly-cloudy-day
# 2010-08-02               rain
# 2010-08-03  partly-cloudy-day
#
#                                                      stations  \
# datetime
# 2010-07-30  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-07-31  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-08-01  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-08-02  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-08-03  376,909,999,903,672,000,000,000,000,000,000,00...
#
#            Number of Bicycle Hires
# datetime
# 2010-07-30                   6,897
# 2010-07-31                   5,564
# 2010-08-01                   4,303
# 2010-08-02                   6,642
# 2010-08-03                   7,966
#               name  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# datetime
# 2024-01-27  London      8.6      1.1   5.0           6.6          -0.6
# 2024-01-28  London     11.5      3.1   7.0          11.5           0.5
# 2024-01-29  London     12.1      8.6  10.8          12.1           7.2
# 2024-01-30  London     12.5      7.6   9.1          12.5           4.9
# 2024-01-31  London     12.1      6.8   8.8          12.1           4.3
#
#             feelslike  dew  humidity  precip  precipprob  precipcover  \
# datetime
# 2024-01-27        3.3  2.0      81.8   0.000           0         0.00
# 2024-01-28        5.4  4.1      82.4   0.000           0         0.00
# 2024-01-29       10.5  8.8      87.3   0.000           0         0.00
# 2024-01-30        7.5  5.3      77.5   0.000           0         0.00
# 2024-01-31        7.5  4.1      72.5   0.199         100         4.17
#
#            preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2024-01-27       rain   0.0        0.0      29.8       18.1    180.3
# 2024-01-28       rain   0.0        0.0      25.9       13.8    169.7
# 2024-01-29       rain   0.0        0.0      33.9       20.8    182.3
# 2024-01-30       rain   0.0        0.0      60.8       29.0    257.7
# 2024-01-31       rain   0.0        0.0      40.7       25.7    231.3
#
#             sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2024-01-27            1032.7        33.1        15.9            46.0
# 2024-01-28            1022.7        33.5        15.2            51.8
# 2024-01-29            1022.0        95.9         8.4            35.6
# 2024-01-30            1027.4        96.1        24.9            15.6
# 2024-01-31            1029.7        98.2        21.9            26.4
#
#             solarenergy  uvindex  severerisk              sunrise  \
# datetime
# 2024-01-27          4.0      3.0        10.0  2024-01-27T07:46:54
# 2024-01-28          4.6      3.0        10.0  2024-01-28T07:45:32
# 2024-01-29          3.1      2.0        10.0  2024-01-29T07:44:08
# 2024-01-30          1.4      1.0        10.0  2024-01-30T07:42:42
# 2024-01-31          2.3      1.0        10.0  2024-01-31T07:41:14
#
#                          sunset  moonphase        conditions  \
# datetime
# 2024-01-27  2024-01-27T16:40:05       0.56  Partially cloudy
# 2024-01-28  2024-01-28T16:41:51       0.59  Partially cloudy
# 2024-01-29  2024-01-29T16:43:39       0.62          Overcast
# 2024-01-30  2024-01-30T16:45:26       0.66          Overcast
# 2024-01-31  2024-01-31T16:47:14       0.69    Rain, Overcast
#
#                                                   description  \
# datetime
# 2024-01-27                  Partly cloudy throughout the day.
# 2024-01-28                  Partly cloudy throughout the day.
# 2024-01-29                   Cloudy skies throughout the day.
# 2024-01-30                   Cloudy skies throughout the day.
# 2024-01-31  Cloudy skies throughout the day with morning r...
#
#                          icon  \
# datetime
# 2024-01-27  partly-cloudy-day
# 2024-01-28  partly-cloudy-day
# 2024-01-29             cloudy
# 2024-01-30             cloudy
# 2024-01-31               rain
#
#                                                      stations  \
# datetime
# 2024-01-27  03769099999,03680099999,F6665,03781099999,0367...
# 2024-01-28  03769099999,03680099999,D4121,03781099999,0367...
# 2024-01-29  03769099999,03680099999,D4121,03781099999,0367...
# 2024-01-30  03769099999,03680099999,D4121,03781099999,0367...
# 2024-01-31  03769099999,03680099999,D4121,03781099999,0367...
#
#            Number of Bicycle Hires
# datetime
# 2024-01-27                  16,959
# 2024-01-28                  15,540
# 2024-01-29                  22,839
# 2024-01-30                  22,303
# 2024-01-31                  24,505
# (4934, 33)

# %%
print(final_dataset.head())
# Out:
#               name  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# datetime
# 2010-07-30  london     22.3     14.0  17.9          22.3          14.0
# 2010-07-31  london     23.5     17.6  20.1          23.5          17.6
# 2010-08-01  london     22.8     15.3  18.8          22.8          15.3
# 2010-08-02  london     22.1     16.3  18.9          22.1          16.3
# 2010-08-03  london     21.8     13.0  18.0          21.8          13.0
#
#             feelslike   dew  humidity  precip  precipprob  precipcover  \
# datetime
# 2010-07-30       17.9  10.5      63.0   0.000           0         0.00
# 2010-07-31       20.1  14.3      71.3   1.995         100         8.33
# 2010-08-01       18.8  11.7      64.8   0.000           0         0.00
# 2010-08-02       18.9  11.1      60.9   0.299         100         4.17
# 2010-08-03       18.0  11.6      67.3   0.000           0         0.00
#
#            preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2010-07-30        NaN   0.0        0.0       NaN       21.3    250.6
# 2010-07-31       rain   0.0        0.0       NaN       22.7    242.6
# 2010-08-01       rain   0.0        0.0       NaN       14.6    261.1
# 2010-08-02       rain   0.0        0.0       NaN       15.1    344.5
# 2010-08-03       rain   0.0        0.0       NaN       20.0    247.9
#
#             sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2010-07-30            1014.8        60.3        32.9           266.8
# 2010-07-31            1011.6        64.1        31.1           250.6
# 2010-08-01            1013.2        62.3        38.7           243.3
# 2010-08-02            1016.6        63.3        36.6           273.9
# 2010-08-03            1016.0        54.3        30.7           273.1
#
#             solarenergy  uvindex  severerisk              sunrise  \
# datetime
# 2010-07-30         23.1      8.0         NaN  2010-07-30T05:20:54
# 2010-07-31         21.7      7.0         NaN  2010-07-31T05:22:23
# 2010-08-01         21.1      7.0         NaN  2010-08-01T05:23:52
# 2010-08-02         23.6      8.0         NaN  2010-08-02T05:25:22
# 2010-08-03         23.4      8.0         NaN  2010-08-03T05:26:53
#
#                          sunset  moonphase              conditions  \
# datetime
# 2010-07-30  2010-07-30T20:52:00       0.65        Partially cloudy
# 2010-07-31  2010-07-31T20:50:25       0.68  Rain, Partially cloudy
# 2010-08-01  2010-08-01T20:48:48       0.71        Partially cloudy
# 2010-08-02  2010-08-02T20:47:09       0.75  Rain, Partially cloudy
# 2010-08-03  2010-08-03T20:45:28       0.75        Partially cloudy
#
#                                                   description  \
# datetime
# 2010-07-30                  Partly cloudy throughout the day.
# 2010-07-31  Partly cloudy throughout the day with rain in ...
# 2010-08-01                  Partly cloudy throughout the day.
# 2010-08-02  Partly cloudy throughout the day with morning ...
# 2010-08-03                  Partly cloudy throughout the day.
#
#                          icon  \
# datetime
# 2010-07-30  partly-cloudy-day
# 2010-07-31               rain
# 2010-08-01  partly-cloudy-day
# 2010-08-02               rain
# 2010-08-03  partly-cloudy-day
#
#                                                      stations  \
# datetime
# 2010-07-30  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-07-31  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-08-01  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-08-02  376,909,999,903,672,000,000,000,000,000,000,00...
# 2010-08-03  376,909,999,903,672,000,000,000,000,000,000,00...
#
#            Number of Bicycle Hires
# datetime
# 2010-07-30                   6,897
# 2010-07-31                   5,564
# 2010-08-01                   4,303
# 2010-08-02                   6,642
# 2010-08-03                   7,966

# %%
print(final_dataset.tail())
# Out:
#               name  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# datetime
# 2024-01-27  London      8.6      1.1   5.0           6.6          -0.6
# 2024-01-28  London     11.5      3.1   7.0          11.5           0.5
# 2024-01-29  London     12.1      8.6  10.8          12.1           7.2
# 2024-01-30  London     12.5      7.6   9.1          12.5           4.9
# 2024-01-31  London     12.1      6.8   8.8          12.1           4.3
#
#             feelslike  dew  humidity  precip  precipprob  precipcover  \
# datetime
# 2024-01-27        3.3  2.0      81.8   0.000           0         0.00
# 2024-01-28        5.4  4.1      82.4   0.000           0         0.00
# 2024-01-29       10.5  8.8      87.3   0.000           0         0.00
# 2024-01-30        7.5  5.3      77.5   0.000           0         0.00
# 2024-01-31        7.5  4.1      72.5   0.199         100         4.17
#
#            preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# datetime
# 2024-01-27       rain   0.0        0.0      29.8       18.1    180.3
# 2024-01-28       rain   0.0        0.0      25.9       13.8    169.7
# 2024-01-29       rain   0.0        0.0      33.9       20.8    182.3
# 2024-01-30       rain   0.0        0.0      60.8       29.0    257.7
# 2024-01-31       rain   0.0        0.0      40.7       25.7    231.3
#
#             sealevelpressure  cloudcover  visibility  solarradiation  \
# datetime
# 2024-01-27            1032.7        33.1        15.9            46.0
# 2024-01-28            1022.7        33.5        15.2            51.8
# 2024-01-29            1022.0        95.9         8.4            35.6
# 2024-01-30            1027.4        96.1        24.9            15.6
# 2024-01-31            1029.7        98.2        21.9            26.4
#
#             solarenergy  uvindex  severerisk              sunrise  \
# datetime
# 2024-01-27          4.0      3.0        10.0  2024-01-27T07:46:54
# 2024-01-28          4.6      3.0        10.0  2024-01-28T07:45:32
# 2024-01-29          3.1      2.0        10.0  2024-01-29T07:44:08
# 2024-01-30          1.4      1.0        10.0  2024-01-30T07:42:42
# 2024-01-31          2.3      1.0        10.0  2024-01-31T07:41:14
#
#                          sunset  moonphase        conditions  \
# datetime
# 2024-01-27  2024-01-27T16:40:05       0.56  Partially cloudy
# 2024-01-28  2024-01-28T16:41:51       0.59  Partially cloudy
# 2024-01-29  2024-01-29T16:43:39       0.62          Overcast
# 2024-01-30  2024-01-30T16:45:26       0.66          Overcast
# 2024-01-31  2024-01-31T16:47:14       0.69    Rain, Overcast
#
#                                                   description  \
# datetime
# 2024-01-27                  Partly cloudy throughout the day.
# 2024-01-28                  Partly cloudy throughout the day.
# 2024-01-29                   Cloudy skies throughout the day.
# 2024-01-30                   Cloudy skies throughout the day.
# 2024-01-31  Cloudy skies throughout the day with morning r...
#
#                          icon  \
# datetime
# 2024-01-27  partly-cloudy-day
# 2024-01-28  partly-cloudy-day
# 2024-01-29             cloudy
# 2024-01-30             cloudy
# 2024-01-31               rain
#
#                                                      stations  \
# datetime
# 2024-01-27  03769099999,03680099999,F6665,03781099999,0367...
# 2024-01-28  03769099999,03680099999,D4121,03781099999,0367...
# 2024-01-29  03769099999,03680099999,D4121,03781099999,0367...
# 2024-01-30  03769099999,03680099999,D4121,03781099999,0367...
# 2024-01-31  03769099999,03680099999,D4121,03781099999,0367...
#
#            Number of Bicycle Hires
# datetime
# 2024-01-27                  16,959
# 2024-01-28                  15,540
# 2024-01-29                  22,839
# 2024-01-30                  22,303
# 2024-01-31                  24,505

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.layers import Activation
from keras.optimizers import SGD

np_data = final_dataset.to_numpy()
X = np_data[:, :32]
y = np_data[:, 32]
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
y_train = y_train.reshape((-1,1))
y_test = y_test.reshape((-1,1))
x_scaler = StandardScaler()
x_train = x_scaler.fit_transform(x_train)
y_scaler = StandardScaler()
y_train = y_scaler.fit_transform(y_train)

# These hyperparameters will be decided based on the validation set later
batch_size = 32
epochs = 100
model = Sequential()
model.add(LSTM(64, activation = "relu", input_shape=(32,))) # Not sure about 64
model.add(Dropout(0.2))
model.add(Dense(64, activation = "relu"))
model.add(Dropout(0.2))
model.add(Dense(1, activation = "linear")) # Not sure about 1
model.compile(loss = "mse", optimizer = SGD(), metrics = ["accuracy"])
model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, verbose = 1, validation_split = 0.1)

# Model validation to find hyperparameters (corret location?)
y_test_model = model.predict(x_test)
accuracy_score = accuracy_score(y_test,y_test_model)
print(accuracy_score)

# Normalisation
x_test = x_scaler.transform(x_test)
y_test = y_scaler.transform(y_test)

score = model.evaluate(x_test, y_test, verbose = 0)
print('Test_loss:', score[0])
print('Test_accuracy:', score[1])
raw_output = model.predict(x_test)
output = y_scaler.inverse_transform(raw_output)
print(output)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-2e1742d12a4d> in <module>
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.metrics import accuracy_score
# ----> 4 import keras
#       5 from keras.models import Sequential
#       6 from keras.layers import Dense, Dropout
#
# ModuleNotFoundError: No module named 'keras'
